# %%
import pandas as pd   # pip install pandas

def read_excel(data, path, sheet):
    data = pd.read_excel(path, sheet_name=sheet, index_col=0) #считываем excel файл
    data = data.reset_index() #
    data = data.rename(columns=lambda x: x if not 'Unnamed' in str(x) else None)
    data = data.dropna(how='all')
    data.columns = pd.Series(data.columns).fillna(method='ffill', axis=0)
    return data

# %%
df_jobs = pd.DataFrame()
df_jobs = read_excel(df_jobs, '../stats/Работа/раб.xls', '1')
df_jobs_c = df_jobs.copy()

# %%
df_jobs_c.head(20)
# Out:
#    Наименование      городов и районов  \
# 0                                  NaN
# 1                       ВСЕГО ПО КРАЮ:
# 2                    Итого по городам:
# 3                            1. Алейск
# 4                           2. Барнаул
# 5                        3. Белокуриха
# 6                             4. Бийск
# 7                           5. Заринск
# 8                       6. Новоалтайск
# 9                          7. Рубцовск
# 10                        8. Славгород
# 11                           9. Яровое
# 12                  10. ЗАТО Сибирский
# 14                   Итого по районам:
# 15                         1. Алейский
# 16                        2. Алтайский
# 17                         3. Баевский
# 18                          4. Бийский
# 19                   5. Благовещенский
# 20                       6. Бурлинский
#
#    Трудоспос. население в трудоспос. возрасте  \
# 0                               на 01.01.2019
# 1                                     1261903
# 2                                      732774
# 3                                       16632
# 4                                      407040
# 5                                        8139
# 6                                      116182
# 7                                       23930
# 8                                       40346
# 9                                       80793
# 10                                      21925
# 11                                       9130
# 12                                       8657
# 14                                     529129
# 15                                       6642
# 16                                      13379
# 17                                       4281
# 18                                      15424
# 19                                      14722
# 20                                       5091
#
#    Трудоспос. население в трудоспос. возрасте.1  \
# 0                                 на 01.01.2020
# 1                                       1255100
# 2                                        736395
# 3                                         16909
# 4                                        410248
# 5                                          8240
# 6                                        115969
# 7                                         23746
# 8                                         41435
# 9                                         80127
# 10                                        21661
# 11                                         9229
# 12                                         8831
# 14                                       518705
# 15                                         6316
# 16                                        13521
# 17                                         4065
# 18                                        15000
# 19                                        14444
# 20                                         4945
#
#     Незанятые граждане,ищущие работу   \
# 0                              2020.0
# 1                             23036.0
# 2                              7782.0
# 3                               146.0
# 4                              3198.0
# 5                               317.0
# 6                              1268.0
# 7                               374.0
# 8                               734.0
# 9                               877.0
# 10                              602.0
# 11                              214.0
# 12                               52.0
# 14                            15254.0
# 15                              155.0
# 16                              133.0
# 17                              243.0
# 18                              314.0
# 19                              406.0
# 20                              276.0
#
#     Незанятые граждане, ищущие работу,              (чел.)  \
# 0                                                 NaN
# 1                                             29184.0
# 2                                             11925.0
# 3                                                77.0
# 4                                              6546.0
# 5                                               174.0
# 6                                              1976.0
# 7                                               312.0
# 8                                              1082.0
# 9                                              1043.0
# 10                                              504.0
# 11                                              166.0
# 12                                               45.0
# 14                                            17259.0
# 15                                               97.0
# 16                                              213.0
# 17                                              352.0
# 18                                              412.0
# 19                                              533.0
# 20                                              236.0
#
#    По сравнению с 01.05.20       (%)  Состоит на учете безраб. (чел.)  \
# 0                                NaN                           2020.0
# 1                         126.688661                          18803.0
# 2                            в 1,5 р                           5670.0
# 3                          52.739726                            118.0
# 4                            в 2,0 р                           2164.0
# 5                           54.88959                            251.0
# 6                            в 1,6 р                            998.0
# 7                           83.42246                            302.0
# 8                         147.411444                            561.0
# 9                         118.928164                            642.0
# 10                          83.72093                            409.0
# 11                         77.570093                            183.0
# 12                         86.538462                             42.0
# 14                        113.144093                          13133.0
# 15                         62.580645                            130.0
# 16                           в 1,6 р                            103.0
# 17                        144.855967                            221.0
# 18                        131.210191                            228.0
# 19                        131.280788                            334.0
# 20                         85.507246                            261.0
#
#     Состоит на учете безработных, (чел.)     \
# 0                                       NaN
# 1                                   27309.0
# 2                                   10577.0
# 3                                      69.0
# 4                                    5918.0
# 5                                     169.0
# 6                                    1610.0
# 7                                     300.0
# 8                                    1056.0
# 9                                     775.0
# 10                                    492.0
# 11                                    150.0
# 12                                     38.0
# 14                                  16732.0
# 15                                     94.0
# 16                                    194.0
# 17                                    338.0
# 18                                    350.0
# 19                                    529.0
# 20                                    236.0
#
#    По сравнению с 01.05.20       (%).1  \
# 0                                  NaN
# 1                           145.237462
# 2                              в 1,9 р
# 3                            58.474576
# 4                              в 2,7 р
# 5                            67.330677
# 6                              в 1,6 р
# 7                            99.337748
# 8                              в 1,9 р
# 9                           120.716511
# 10                          120.293399
# 11                           81.967213
# 12                            90.47619
# 14                          127.404249
# 15                           72.307692
# 16                             в 1,9 р
# 17                             в 1,5 р
# 18                             в 1,5 р
# 19                             в 1,6 р
# 20                           90.421456
#
#     В т.ч. с назначением пособия по безраб. (чел.)\n  \
# 0                                             2020.0
# 1                                            15933.0
# 2                                             4766.0
# 3                                              101.0
# 4                                             1786.0
# 5                                              231.0
# 6                                              831.0
# 7                                              230.0
# 8                                              504.0
# 9                                              559.0
# 10                                             339.0
# 11                                             146.0
# 12                                              39.0
# 14                                           11167.0
# 15                                             117.0
# 16                                              83.0
# 17                                             195.0
# 18                                             192.0
# 19                                             284.0
# 20                                             236.0
#
#     В т.ч. с назначением пособия по безработице, (чел.)   \
# 0                                                 NaN
# 1                                             18940.0
# 2                                              5932.0
# 3                                                62.0
# 4                                              2804.0
# 5                                               142.0
# 6                                              1140.0
# 7                                               205.0
# 8                                               586.0
# 9                                               457.0
# 10                                              383.0
# 11                                              122.0
# 12                                               31.0
# 14                                            13008.0
# 15                                               83.0
# 16                                              167.0
# 17                                              196.0
# 18                                              249.0
# 19                                              404.0
# 20                                              221.0
#
#    По сравнению с 01.05.20       (%).2
# 0                                  NaN
# 1                            118.87278
# 2                            124.46496
# 3                            61.386139
# 4                              в 1,6 р
# 5                            61.471861
# 6                           137.184116
# 7                            89.130435
# 8                           116.269841
# 9                            81.753131
# 10                          112.979351
# 11                           83.561644
# 12                           79.487179
# 14                          116.486075
# 15                           70.940171
# 16                             в 2,0 р
# 17                          100.512821
# 18                            129.6875
# 19                          142.253521
# 20                           93.644068
